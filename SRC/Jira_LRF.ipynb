# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window

Source_Data='/Volumes/workspace/data/employee_etl/Source_Data'
Temp='/Volumes/workspace/data/employee_etl/tmp'
Output='/Volumes/workspace/data/employee_etl/Output'

# %%
df=spark.read.csv(Source_Data+'/employee_jira.csv',header=True,inferSchema=True)
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_Id</th><th>Emp_Name</th><th>Jira_Points</th></tr></thead><tbody><tr><td>E001</td><td>John Doe</td><td>128</td></tr><tr><td>E002</td><td>Jane Smith</td><td>95</td></tr><tr><td>E003</td><td>Akira Tanaka</td><td>152</td></tr><tr><td>E004</td><td>Maria Garcia</td><td>86</td></tr><tr><td>E005</td><td>Chen Wei</td><td>110</td></tr></tbody></table></div>

# %%
df=df.drop(col("Emp_Name")).withColumn('Percentage',round(col('Jira_Points')/200*100,2)) 
    
    
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Emp_Id</th><th>Jira_Points</th><th>Percentage</th></tr></thead><tbody><tr><td>E001</td><td>128</td><td>64.0</td></tr><tr><td>E002</td><td>95</td><td>47.5</td></tr><tr><td>E003</td><td>152</td><td>76.0</td></tr><tr><td>E004</td><td>86</td><td>43.0</td></tr><tr><td>E005</td><td>110</td><td>55.0</td></tr></tbody></table></div>

# %%
df.write.mode('overwrite').parquet(Temp + '/Jira_LRF.parquet')
